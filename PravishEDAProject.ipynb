# %% [markdown]
# <a href="https://colab.research.google.com/github/pravishmisra311-lgtm/pravish_eda1/blob/main/PravishEDAProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np #numpy
import pandas as pd #pandas
import matplotlib.pyplot as plt #visualising data
# %matplotlib inline
import seaborn as sns #seaborn

# %%
#import csv file --csv = comma seperated values
df=pd.read_csv('/content/Diwali Sales Data.csv',encoding='unicode_escape')
#provide access df to read data
#unicode escape reads special character

# %%
df.shape #rows x col
# Out:
# (11251, 15)

# %%
df.head() #top 5 values
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(['Status','unnamed1'],axis=1,inplace=True)
 #drop,axis=1,inplace=True
 #status and unnamed1 is removed

# %%
#check for null values
pd.isnull(df).sum() #.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)
#drop null values

# %%
df['Amount']=df['Amount'].astype('int')
#change data type

# %%
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns={'Marital_Status':'Marriage'}) #rename column

# %%
df.describe()
#returns description of the data in the DataFrame
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df[['Age','Orders','Amount']].describe() #.describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %%
#Exploratory Data Analysis -EDA

# %%
ax=sns.countplot(x='Gender',data=df)
for bars in ax.containers:
  ax.bar_label(bars)
  #plotting a bar chart for Gender and it's count

# %%
sales_gen=df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
#groupby(['Gender'],as_index=False)
sns.barplot(x='Gender',y='Amount',data=sales_gen)#barplot
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Re-loading and cleaning data to ensure 'df' is populated
df = pd.read_csv('/content/Diwali Sales Data.csv', encoding='unicode_escape')
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)
df.dropna(inplace=True)
df['Amount'] = df['Amount'].astype('int')

# Regenerating the plot
plt.figure(figsize=(10, 5))
ax = sns.countplot(data=df, x='Age Group', hue='Gender')

for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %%
# Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

plt.figure(figsize=(10, 5))
sns.barplot(x='Age Group', y='Amount', data=sales_age)
plt.title('Total Sales Amount by Age Group')
plt.show()

# %%
# Total number of orders from top 10 states
sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

plt.figure(figsize=(15, 5))
sns.barplot(data=sales_state, x='State', y='Orders')
plt.title('Top 10 States by Total Number of Orders')
plt.show()

# %%
# Total amount/sales from top 10 states
sales_state_amount = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

plt.figure(figsize=(15, 5))
sns.barplot(data=sales_state_amount, x='State', y='Amount')
plt.title('Top 10 States by Total Sales Amount')
plt.show()

# %%
ax = sns.countplot(data = df, x = 'Marital_Status')

plt.figure(figsize=(7, 5))
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
# Total Amount vs Marital Status and Gender
sales_marital_gen = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

plt.figure(figsize=(10, 5))
sns.barplot(data=sales_marital_gen, x='Marital_Status', y='Amount', hue='Gender')
plt.title('Total Sales Amount by Marital Status and Gender')
plt.show()

# %%
plt.figure(figsize=(20, 5))
ax = sns.countplot(data=df, x='Occupation', order=df['Occupation'].value_counts().index)

for bars in ax.containers:
    ax.bar_label(bars)

plt.title('Distribution of Customers by Occupation')
plt.show()

# %%
# Total Amount vs Occupation
sales_occ = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

plt.figure(figsize=(20, 5))
sns.barplot(data=sales_occ, x='Occupation', y='Amount')
plt.title('Total Sales Amount by Occupation')
plt.show()

# %%
plt.figure(figsize=(20, 5))
ax = sns.countplot(data=df, x='Product_Category', order=df['Product_Category'].value_counts().index)

for bars in ax.containers:
    ax.bar_label(bars)

plt.title('Number of Orders per Product Category')
plt.xticks(rotation=45)
plt.show()

# %%
sales_pc = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

plt.figure(figsize=(20, 5))
sns.barplot(data=sales_pc, x='Product_Category', y='Amount')
plt.title('Top 10 Product Categories by Total Sales Amount')
plt.xticks(rotation=45)
plt.show()

# %%
sales_pc_total = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

plt.figure(figsize=(20, 5))
sns.barplot(data=sales_pc_total, x='Product_Category', y='Amount')
plt.title('Total Sales Amount by Product Category')
plt.xticks(rotation=45)
plt.show()

# %%
sales_product = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

plt.figure(figsize=(20, 5))
sns.barplot(data=sales_product, x='Product_ID', y='Orders')
plt.title('Top 10 Most Ordered Products')
plt.show()

# %%
sales_product_amt = df.groupby(['Product_ID'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

plt.figure(figsize=(20, 5))
sns.barplot(data=sales_product_amt, x='Product_ID', y='Amount')
plt.title('Top 10 Most Sold Products (by Amount)')
plt.show()
